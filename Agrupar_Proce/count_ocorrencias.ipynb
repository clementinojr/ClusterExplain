# %%
#Buscar - Local quantidade de

# %%
import sys
import os
import inspect
import pandas as pd
import sys 
from pylab import *
import sklearn
import sklearn.datasets
import sklearn.ensemble
import numpy as np
import lime
import lime.lime_tabular
#from __future__ import print_function
np.random.seed(1)
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import random
import dataframe_image as dfi
from PIL import Image
import os
import six
from bokeh.io import export_png, export_svgs
from bokeh.models import ColumnDataSource, DataTable, TableColumn
from datetime import datetime

# %%
def read_csv(name_df,path):
    name_df = pd.read_csv(path+".csv")
    return name_df

# %%
df_intial = read_csv('df', 'df5')

# %%
df = df_intial.query('Labels == 9')

# %%
df
# Out:
#                                         Nome_Ocorrencia  Labels  \
# 6036        Infarto agudo do miocardio nao especificado       9
# 6037  Corte, puncao, perfuracao ou hemorragia aciden...       9
# 6038                        Insuficiencia renal cronica       9
# 6039                         Infarto agudo do miocardio       9
# 6040  Acidente vascular cerebral, nao especificado c...       9
# ...                                                 ...     ...
# 6503                   ANGIOPLASTIA CORONÁRIA COM STENT       9
# 6504                                    Angina instavel       9
# 6505                   Hipertensao essencial (primaria)       9
# 6506          Infarto agudo subendocardico do miocardio       9
# 6507  Diabetes mellitus insulino-dependente com comp...       9
#
#                     ID  __de_saturacao_da_transferrina  \
# 6036  1379673504316278                             0.0
# 6037  6610997289411405                             0.0
# 6038  6610997289411405                             0.0
# 6039  8462620560974586                             0.0
# 6040  8462620560974586                             0.0
# ...                ...                             ...
# 6503   301372344255913                             0.0
# 6504   301372344255913                             0.0
# 6505  3860686325023548                             0.0
# 6506  3860686325023548                             0.0
# 6507  3860686325023548                             0.0
#
#       ac__anti_t_cruzi__doen_a_de_chagas_  \
# 6036                                  0.0
# 6037                                  0.0
# 6038                                  0.0
# 6039                                  0.0
# 6040                                  0.0
# ...                                   ...
# 6503                                  0.0
# 6504                                  0.0
# 6505                                  0.0
# 6506                                  0.0
# 6507                                  0.0
#
#       ac__anticardiolipina___iga__igg_e_igm__  \
# 6036                                      0.0
# 6037                                      0.0
# 6038                                      0.0
# 6039                                      0.0
# 6040                                      0.0
# ...                                       ...
# 6503                                      0.0
# 6504                                      0.0
# 6505                                      0.0
# 6506                                      0.0
# 6507                                      0.0
#
#       acesso_p__hemodialise__conf__fistula_art__venosa_s_enxerto  \
# 6036                                                0.0
# 6037                                                0.0
# 6038                                                0.0
# 6039                                                0.0
# 6040                                                0.0
# ...                                                 ...
# 6503                                                0.0
# 6504                                                0.0
# 6505                                                0.0
# 6506                                                0.0
# 6507                                                0.0
#
#       acesso_para_hemodialise_com_implante_de_cateter_de_duplo_lumem_na_ira  \
# 6036                                                0.0
# 6037                                                0.0
# 6038                                                0.0
# 6039                                                0.0
# 6040                                                0.0
# ...                                                 ...
# 6503                                                0.0
# 6504                                                0.0
# 6505                                                0.0
# 6506                                                0.0
# 6507                                                0.0
#
#       acido_folico  acido_urico  ...  urina_tipo_i  urocultura_  \
# 6036           0.0          0.0  ...           0.0          0.0
# 6037           0.0          0.0  ...           0.0          0.0
# 6038           0.0          0.0  ...           0.0          0.0
# 6039           0.0          0.0  ...           0.0          0.0
# 6040           0.0          0.0  ...           0.0          0.0
# ...            ...          ...  ...           ...          ...
# 6503           0.0          0.0  ...           0.0          0.0
# 6504           0.0          0.0  ...           0.0          0.0
# 6505           0.0          0.0  ...           0.0          0.0
# 6506           0.0          0.0  ...           0.0          0.0
# 6507           0.0          0.0  ...           0.0          0.0
#
#       valvo_pulmonar  vancomicina  velocidade_de_hemossedimentacao___vhs__  \
# 6036             0.0          0.0                                      0.0
# 6037             0.0          0.0                                      0.0
# 6038             0.0          0.0                                      0.0
# 6039             0.0          0.0                                      0.0
# 6040             0.0          0.0                                      0.0
# ...              ...          ...                                      ...
# 6503             0.0          0.0                                      0.0
# 6504             0.0          0.0                                      0.0
# 6505             0.0          0.0                                      0.0
# 6506             0.0          0.0                                      0.0
# 6507             0.0          0.0                                      0.0
#
#       ventilador  ventilador_respirador  verificacao_de_sinais_vitais_  \
# 6036         0.0                    0.0                            0.0
# 6037         0.0                    0.0                            0.0
# 6038         0.0                    0.0                            0.0
# 6039         0.0                    0.0                            0.0
# 6040         0.0                    0.0                            0.0
# ...          ...                    ...                            ...
# 6503         0.0                    0.0                            0.0
# 6504         0.0                    0.0                            0.0
# 6505         0.0                    0.0                            0.0
# 6506         0.0                    0.0                            0.0
# 6507         0.0                    0.0                            0.0
#
#       vitamina_b12  western_blott_para_hiv
# 6036           0.0                     0.0
# 6037           0.0                     0.0
# 6038           0.0                     0.0
# 6039           0.0                     0.0
# 6040           0.0                     0.0
# ...            ...                     ...
# 6503           0.0                     0.0
# 6504           0.0                     0.0
# 6505           0.0                     0.0
# 6506           0.0                     0.0
# 6507           0.0                     0.0
#
# [472 rows x 546 columns]

# %% [markdown]
# Removendo linhas duplicadas

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#                                         Nome_Ocorrencia  Labels  \
# 6036        Infarto agudo do miocardio nao especificado       9
# 6037  Corte, puncao, perfuracao ou hemorragia aciden...       9
# 6038                        Insuficiencia renal cronica       9
# 6039                         Infarto agudo do miocardio       9
# 6040  Acidente vascular cerebral, nao especificado c...       9
# ...                                                 ...     ...
# 6494                    Hiperlipidemia nao especificada       9
# 6495  Infarto agudo transmural da parede inferior do...       9
# 6500  Outras formas de doenca isquemica aguda do cor...       9
# 6501                   ANGIOPLASTIA CORONÁRIA COM STENT       9
# 6502                                    Angina instavel       9
#
#                     ID  __de_saturacao_da_transferrina  \
# 6036  1379673504316278                             0.0
# 6037  6610997289411405                             0.0
# 6038  6610997289411405                             0.0
# 6039  8462620560974586                             0.0
# 6040  8462620560974586                             0.0
# ...                ...                             ...
# 6494  3869919716240150                             0.0
# 6495  3869919716240150                             0.0
# 6500  3129801073319802                             0.0
# 6501   301372344255913                             0.0
# 6502   301372344255913                             0.0
#
#       ac__anti_t_cruzi__doen_a_de_chagas_  \
# 6036                                  0.0
# 6037                                  0.0
# 6038                                  0.0
# 6039                                  0.0
# 6040                                  0.0
# ...                                   ...
# 6494                                  0.0
# 6495                                  0.0
# 6500                                  0.0
# 6501                                  0.0
# 6502                                  0.0
#
#       ac__anticardiolipina___iga__igg_e_igm__  \
# 6036                                      0.0
# 6037                                      0.0
# 6038                                      0.0
# 6039                                      0.0
# 6040                                      0.0
# ...                                       ...
# 6494                                      0.0
# 6495                                      0.0
# 6500                                      0.0
# 6501                                      0.0
# 6502                                      0.0
#
#       acesso_p__hemodialise__conf__fistula_art__venosa_s_enxerto  \
# 6036                                                0.0
# 6037                                                0.0
# 6038                                                0.0
# 6039                                                0.0
# 6040                                                0.0
# ...                                                 ...
# 6494                                                0.0
# 6495                                                0.0
# 6500                                                0.0
# 6501                                                0.0
# 6502                                                0.0
#
#       acesso_para_hemodialise_com_implante_de_cateter_de_duplo_lumem_na_ira  \
# 6036                                                0.0
# 6037                                                0.0
# 6038                                                0.0
# 6039                                                0.0
# 6040                                                0.0
# ...                                                 ...
# 6494                                                0.0
# 6495                                                0.0
# 6500                                                0.0
# 6501                                                0.0
# 6502                                                0.0
#
#       acido_folico  acido_urico  ...  urina_tipo_i  urocultura_  \
# 6036           0.0          0.0  ...           0.0          0.0
# 6037           0.0          0.0  ...           0.0          0.0
# 6038           0.0          0.0  ...           0.0          0.0
# 6039           0.0          0.0  ...           0.0          0.0
# 6040           0.0          0.0  ...           0.0          0.0
# ...            ...          ...  ...           ...          ...
# 6494           0.0          0.0  ...           0.0          0.0
# 6495           0.0          0.0  ...           0.0          0.0
# 6500           0.0          0.0  ...           0.0          0.0
# 6501           0.0          0.0  ...           0.0          0.0
# 6502           0.0          0.0  ...           0.0          0.0
#
#       valvo_pulmonar  vancomicina  velocidade_de_hemossedimentacao___vhs__  \
# 6036             0.0          0.0                                      0.0
# 6037             0.0          0.0                                      0.0
# 6038             0.0          0.0                                      0.0
# 6039             0.0          0.0                                      0.0
# 6040             0.0          0.0                                      0.0
# ...              ...          ...                                      ...
# 6494             0.0          0.0                                      0.0
# 6495             0.0          0.0                                      0.0
# 6500             0.0          0.0                                      0.0
# 6501             0.0          0.0                                      0.0
# 6502             0.0          0.0                                      0.0
#
#       ventilador  ventilador_respirador  verificacao_de_sinais_vitais_  \
# 6036         0.0                    0.0                            0.0
# 6037         0.0                    0.0                            0.0
# 6038         0.0                    0.0                            0.0
# 6039         0.0                    0.0                            0.0
# 6040         0.0                    0.0                            0.0
# ...          ...                    ...                            ...
# 6494         0.0                    0.0                            0.0
# 6495         0.0                    0.0                            0.0
# 6500         0.0                    0.0                            0.0
# 6501         0.0                    0.0                            0.0
# 6502         0.0                    0.0                            0.0
#
#       vitamina_b12  western_blott_para_hiv
# 6036           0.0                     0.0
# 6037           0.0                     0.0
# 6038           0.0                     0.0
# 6039           0.0                     0.0
# 6040           0.0                     0.0
# ...            ...                     ...
# 6494           0.0                     0.0
# 6495           0.0                     0.0
# 6500           0.0                     0.0
# 6501           0.0                     0.0
# 6502           0.0                     0.0
#
# [150 rows x 546 columns]

# %% [markdown]
# Quantidade de internações com ID diferentes

# %%
len(df["ID"].unique())
# Out:
# 61

# %%
t = list(df['Nome_Ocorrencia'].unique())

# %%
for i in t:
    df_i = df.query('Nome_Ocorrencia == @i')
    qnt =(len(df_i['ID'].unique()))
    print(i, "=" , str(qnt))
    #print(i)
# Out:
# Infarto agudo do miocardio nao especificado = 8
# Corte, puncao, perfuracao ou hemorragia acidentais durante cateterismo cardiaco = 1
# Insuficiencia renal cronica = 2
# Infarto agudo do miocardio = 10
# Acidente vascular cerebral, nao especificado como hemorragico ou isquemico = 2
# Hipercolesterolemia pura = 6
# Hipertensao essencial (primaria) = 22
# Infarto agudo subendocardico do miocardio = 4
# Hidrocefalia = 1
# Doenca aterosclerotica do coracao = 2
# Doencas vasculares perifericas nao especificada = 1
# Uso do tabaco = 5
# Presenca de implante e enxerto de angioplastia coronaria = 5
# Achados anormais de exames para diagnostico por imagem do coracao e da circulacao coronariana = 1
# Miocardiopatia isquemica = 3
# Angina pectoris = 1
# Historia familiar de doenca isquêmica do coracao e outras doencas do aparelho circulatorio = 1
# Uso nocivo para a saude de fumo = 1
# Distorbios do metabolismo de lipoproteinas e outras lipidemias = 4
# Angina instavel = 7
# Diabetes mellitus nao especificado = 1
# Hiperlipidemia nao especificada = 5
# ANGIOPLASTIA CORONÁRIA COM STENT = 5
# Obesidade nao especificada = 1
# Infarto agudo transmural da parede anterior do miocardio = 1
# FIBRILAÇÃO ATRIAL COM RESPOSTA VENTRICULAR RÁPIDA = 1
# Doenca isquemica cronica do coracao = 2
# Outras formas de doenca isquemica aguda do coracao = 4
# CIRURGIA DE REVASCULARIZAÇÃO DO MIOCÁRDIO = 2
# IAM - INFARTO AGUDO TRANSMURAL DE PAREDE INFERIOR DO MIOCÁRDIO = 2
# Infarto agudo transmural da parede inferior do miocardio = 3
# Dor precordial = 2
# Infarto antigo do miocardio = 3
# Outras hiperlipidemias = 1
# Bloqueio atrioventricular de segundo grau = 1
# Presenca de marca-passo cardiaco = 1
# Sindrome de pre-excitacao = 1
# Diabetes mellitus nao-insulino-dependente = 2
# Neoplasia maligna da mama = 1
# Varizes dos membros inferiores com ulcera = 1
# Hiperplasia da prostata = 1
# Insuficiencia cardiaca = 1
# Insuficiencia cardiaca congestiva = 2
# Hiperlipidemia mista = 1
# Dor toracica, nao especificada = 1
# Bloqueio atrioventricular total = 1
# Diabetes mellitus insulino-dependente = 1
# HIPERTENSÃO ARTERIAL SISTÊMICA = 1
# MIOCARDIOPATIA ISQUÊMICA = 1
# Diabetes mellitus nao-insulino-dependente sem complicacoes = 2
# INSUFICIÊNCIA CARDÍACA CONGESTIVA = 1
# Fistula arteriovenosa adquirida = 1
# Insuficiencia cardiaca nao especificada = 1
# Diabetes mellitus insulino-dependente com complicacoes circulatorias perifericas = 1
# Doenca de Chagas (cronica) com comprometimento cardiaco = 1
# Efeito toxico do tabaco e da nicotina = 1
# Presenca de enxerto de ponte [bypass] aortocoronaria = 1
# INFARTO AGUDO = 1
# Uso nocivo para a saude de alcool = 1
# Pneumonia bacteriana nao classificada em outra parte = 1
# IAM - INFARTO AGUDO SUBENDOCÁRDICO DO MIOCÁRDIO = 1
